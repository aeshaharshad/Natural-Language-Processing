# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\hp\appdata\roaming\python\python313\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\hp\appdata\roaming\python\python313\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\hp\appdata\roaming\python\python313\site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\appdata\roaming\python\python313\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\hp\appdata\roaming\python\python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome,to NLP codes.
Please do practice! to become expert in NLP.
"""

# %%
corpus
# Out:
# 'Hello Welcome,to NLP codes.\nPlease do practice! to become expert in NLP.\n'

# %%
## Tokenization
## paragraphs --> sentence
from nltk.tokenize import sent_tokenize
sent_tokenize(corpus)
# Out:
# ['Hello Welcome,to NLP codes.',
#  'Please do practice!',
#  'to become expert in NLP.']

# %%
documents = sent_tokenize(corpus)

# %%
documents
# Out:
# ['Hello Welcome,to NLP codes.',
#  'Please do practice!',
#  'to become expert in NLP.']

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to NLP codes.
# Please do practice!
# to become expert in NLP.

# %%
## Tokenization
## paragraphs --> words
## sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'NLP',
#  'codes',
#  '.',
#  'Please',
#  'do',
#  'practice',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'NLP', 'codes', '.']
# ['Please', 'do', 'practice', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
# make sure each puntuation is also tokenized
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'NLP',
#  'codes',
#  '.',
#  'Please',
#  'do',
#  'practice',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'NLP',
#  'codes.',
#  'Please',
#  'do',
#  'practice',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
